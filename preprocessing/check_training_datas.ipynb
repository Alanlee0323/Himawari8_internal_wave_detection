# %% [markdown]
# ### 先比較 training_imgs 是否有與 training_masks 有不重複

# %%
import os

def check_files(image_dir, mask_dir):
    """
    比對兩個資料夾中的檔案，檢查是否配對
    """
    # 獲取所有檔案名稱
    image_files = [f.replace('.png', '') for f in os.listdir(image_dir) if f.endswith('.png')]
    mask_files = [f.replace('_mask.png', '') for f in os.listdir(mask_dir) if f.endswith('_mask.png')]
    
    # 找出不配對的檔案
    missing_masks = set(image_files) - set(mask_files)
    missing_images = set(mask_files) - set(image_files)
    
    print(f"\n{'='*50}")
    print(f"檔案配對檢查結果:")
    print(f"{'='*50}")
    print(f"訓練圖片數量: {len(image_files)}")
    print(f"Mask圖片數量: {len(mask_files)}")
    
    if missing_masks:
        print(f"\n缺少mask的檔案 ({len(missing_masks)} 個):")
        print(f"{'-'*40}")
        for f in sorted(missing_masks):
            print(f"- {f}.png -> 缺少 {f}_mask.png")
            
    if missing_images:
        print(f"\n缺少原始圖片的檔案 ({len(missing_images)} 個):")
        print(f"{'-'*40}")
        for f in sorted(missing_images):
            print(f"- {f}_mask.png -> 缺少 {f}.png")
    
    if not missing_masks and not missing_images:
        print("\n所有檔案都有正確配對！")

    # # 刪除缺少mask的原始圖片
    # for f in missing_masks:
    #     file_path = os.path.join(image_dir, f + '.png')
    #     if os.path.exists(file_path):
    #         os.remove(file_path)
    #         print(f"已刪除: {f}.png")
       
    #    # 刪除缺少原始圖片的mask
    # for f in missing_images:
    #     file_path = os.path.join(mask_dir, f + '_mask.png')
    #     if os.path.exists(file_path):
    #         os.remove(file_path)
    #         print(f"已刪除: {f}_mask.png")
    
    # 顯示清理後的統計
    remaining_images = len([f for f in os.listdir(image_dir) if f.endswith('.png')])
    remaining_masks = len([f for f in os.listdir(mask_dir) if f.endswith('_mask.png')])
    print(f"\n{'='*50}")
    print(f"清理後的檔案統計:")
    print(f"{'='*50}")
    print(f"訓練圖片數量: {remaining_images}")
    print(f"Mask圖片數量: {remaining_masks}")

# 使用範例
if __name__ == "__main__":
    # 設定資料夾路徑
    train_dir = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\imgs"  # 替換成你的訓練圖片資料夾路徑
    gt_dir = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\mask"        # 替換成你的GT圖片資料夾路徑
    
    try:
        check_files(train_dir, gt_dir)
    except Exception as e:
        print(f"發生錯誤: {str(e)}")
# Out:
# ==================================================
# 檔案配對檢查結果:
# ==================================================
# 訓練圖片數量: 378
# Mask圖片數量: 378
#
# 所有檔案都有正確配對！
#
# ==================================================
# 清理後的檔案統計:
# ==================================================
# 訓練圖片數量: 378
# Mask圖片數量: 378

# %%
import os
import shutil
import random
from pathlib import Path

def verify_pairs(imgs_dir, masks_dir):
    """
    驗證圖片和遮罩是否完全配對，考慮 _mask 後綴
    """
    # 獲取所有檔案名稱並移除副檔名
    img_files = {os.path.splitext(f)[0] for f in os.listdir(imgs_dir) if f.endswith(('.png', '.jpg', '.jpeg'))}
    mask_files = {os.path.splitext(f)[0].replace('_mask', '') for f in os.listdir(masks_dir) if f.endswith(('.png', '.jpg', '.jpeg'))}
    
    # 檢查是否有遺漏的配對
    imgs_without_masks = img_files - mask_files
    masks_without_imgs = mask_files - img_files
    
    if imgs_without_masks:
        print("警告：以下圖片沒有對應的遮罩：")
        for img in sorted(imgs_without_masks):
            print(f"  - {img}.png")
    
    if masks_without_imgs:
        print("警告：以下遮罩沒有對應的圖片：")
        for mask in sorted(masks_without_imgs):
            print(f"  - {mask}_mask.png")
    
    return len(imgs_without_masks) == 0 and len(masks_without_imgs) == 0

def split_dataset(source_imgs_dir, source_masks_dir, output_base_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15, random_seed=42):
    """
    Split dataset into train, validation and test sets while maintaining the pairing between images and masks.
    """
    # 先驗證源資料的配對完整性
    print("驗證源資料配對...")
    if not verify_pairs(source_imgs_dir, source_masks_dir):
        raise ValueError("源資料中的圖片和遮罩配對不完整！請檢查資料集。")
    
    # Set random seed for reproducibility
    random.seed(random_seed)
    
    # Create output directories
    splits = ['train', 'val', 'test']
    for split in splits:
        for subdir in ['imgs', 'masks']:
            os.makedirs(os.path.join(output_base_dir, split, subdir), exist_ok=True)
    
    # Get list of image files
    img_files = [f for f in os.listdir(source_imgs_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    # 確保順序一致
    img_files.sort()
    random.shuffle(img_files)
    
    # Calculate split sizes
    total_size = len(img_files)
    train_size = int(total_size * train_ratio)
    val_size = int(total_size * val_ratio)
    
    # Split the files
    train_files = img_files[:train_size]
    val_files = img_files[train_size:train_size + val_size]
    test_files = img_files[train_size + val_size:]
    
    def copy_files(file_list, split_name):
        for filename in file_list:
            # 準備檔案名稱
            base_name = os.path.splitext(filename)[0]
            ext = os.path.splitext(filename)[1]
            
            # Copy image
            src_img = os.path.join(source_imgs_dir, filename)
            dst_img = os.path.join(output_base_dir, split_name, 'imgs', filename)
            
            # Copy corresponding mask (with _mask suffix)
            mask_filename = f"{base_name}_mask{ext}"
            src_mask = os.path.join(source_masks_dir, mask_filename)
            dst_mask = os.path.join(output_base_dir, split_name, 'masks', mask_filename)
            
            # 確認檔案存在
            if not os.path.exists(src_img):
                raise FileNotFoundError(f"找不到圖片：{src_img}")
            if not os.path.exists(src_mask):
                raise FileNotFoundError(f"找不到遮罩：{src_mask}")
            
            # 複製檔案
            shutil.copy2(src_img, dst_img)
            shutil.copy2(src_mask, dst_mask)
    
    # Copy files to respective directories
    print("正在複製訓練集...")
    copy_files(train_files, 'train')
    print("正在複製驗證集...")
    copy_files(val_files, 'val')
    print("正在複製測試集...")
    copy_files(test_files, 'test')
    
    # 驗證分割後的資料集
    print("\n驗證分割後的資料集...")
    for split in splits:
        print(f"\n檢查 {split} 集的配對...")
        split_imgs_dir = os.path.join(output_base_dir, split, 'imgs')
        split_masks_dir = os.path.join(output_base_dir, split, 'masks')
        verify_pairs(split_imgs_dir, split_masks_dir)
    
    # Print statistics
    print("\n資料集分割完成:")
    print(f"總圖片數量: {total_size}")
    print(f"訓練集: {len(train_files)} 張 ({train_ratio*100:.1f}%)")
    print(f"驗證集: {len(val_files)} 張 ({val_ratio*100:.1f}%)")
    print(f"測試集: {len(test_files)} 張 ({test_ratio*100:.1f}%)")

if __name__ == "__main__":
    # Define your directories
    source_imgs_dir = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_noIW\imgs"
    source_masks_dir = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_noIW\mask"
    output_base_dir = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_noIW\split"
    
    # Run the split
    split_dataset(source_imgs_dir, source_masks_dir, output_base_dir)
# Out:
# 驗證源資料配對...
# 正在複製訓練集...
# 正在複製驗證集...
# 正在複製測試集...
#
# 驗證分割後的資料集...
#
# 檢查 train 集的配對...
#
# 檢查 val 集的配對...
#
# 檢查 test 集的配對...
#
# 資料集分割完成:
# 總圖片數量: 1076
# 訓練集: 753 張 (70.0%)
# 驗證集: 161 張 (15.0%)
# 測試集: 162 張 (15.0%)

# %%
import os
import shutil
from pathlib import Path
import glob

def merge_image_folders(base_path, source_folders, destination_folder):
    """
    將多個來源資料夾中的圖片合併到目標資料夾，支援 imgs 和 masks 子資料夾
    """
    print("\n=== 開始執行合併作業 ===")
    print(f"基礎路徑: {base_path}")
    print(f"目標資料夾: {destination_folder}")
    
    # 建立目標資料夾結構
    full_dest_path = os.path.join(base_path, destination_folder)
    dest_imgs_path = os.path.join(full_dest_path, 'imgs')
    dest_masks_path = os.path.join(full_dest_path, 'masks')
    
    os.makedirs(dest_imgs_path, exist_ok=True)
    os.makedirs(dest_masks_path, exist_ok=True)
    
    # 支援的圖片格式
    image_extensions = ['.jpg', '.jpeg', '.png', '.tif', '.tiff',
                       '.JPG', '.JPEG', '.PNG', '.TIF', '.TIFF']
    
    # 統計資訊
    stats = {
        'total_files_moved': {'imgs': 0, 'masks': 0},
        'files_per_source': {},
        'file_types_found': set()
    }
    
    # 處理每個來源資料夾
    for source_folder in source_folders:
        full_source_path = os.path.join(base_path, source_folder)
        print(f"\n檢查來源資料夾: {source_folder}")
        
        if not os.path.exists(full_source_path):
            print(f"警告: 來源資料夾不存在 - {full_source_path}")
            continue
        
        stats['files_per_source'][source_folder] = {'imgs': 0, 'masks': 0}
        
        # 處理 train, val, test 子資料夾
        for split_folder in ['train', 'val', 'test']:
            split_path = os.path.join(full_source_path, split_folder)
            if not os.path.exists(split_path):
                continue
                
            print(f"\n處理 {split_folder} 資料夾:")
            
            # 處理 imgs 和 masks 資料夾
            for data_type in ['imgs', 'masks']:
                data_path = os.path.join(split_path, data_type)
                if not os.path.exists(data_path):
                    print(f"  {data_type} 資料夾不存在: {data_path}")
                    continue
                    
                print(f"  檢查 {data_type} 資料夾: {data_path}")
                
                # 搜尋所有檔案並記錄類型
                all_files = glob.glob(os.path.join(data_path, '*.*'))
                for file in all_files:
                    ext = os.path.splitext(file)[1].lower()
                    stats['file_types_found'].add(ext)
                    
                    # 只處理圖片檔案
                    if ext.lower() in [x.lower() for x in image_extensions]:
                        try:
                            file_name = os.path.basename(file)
                            # 根據類型選擇目標資料夾
                            dest_path = dest_imgs_path if data_type == 'imgs' else dest_masks_path
                            dest_file = os.path.join(dest_path, file_name)
                            
                            # 處理檔案名稱衝突
                            if os.path.exists(dest_file):
                                base_name, ext = os.path.splitext(file_name)
                                new_name = f"{base_name}_{source_folder}_{split_folder}{ext}"
                                dest_file = os.path.join(dest_path, new_name)
                            
                            shutil.copy2(file, dest_file)
                            stats['total_files_moved'][data_type] += 1
                            stats['files_per_source'][source_folder][data_type] += 1
                            print(f"    複製檔案: {file_name} → {os.path.basename(dest_file)}")
                            
                        except Exception as e:
                            print(f"    錯誤: 複製檔案失敗 {file}: {str(e)}")
    
    return stats

def main():
    # 設定基礎路徑和資料夾名稱
    base_path = r"C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031"
    source_folders = ['20241031_train_IW', '20241031_train_noIW']
    destination_folder = '20241031dataset'
    
    try:
        stats = merge_image_folders(base_path, source_folders, destination_folder)
        
        if stats:
            print("\n=== 處理結果統計 ===")
            print(f"總共移動的檔案:")
            print(f"- 圖片 (imgs): {stats['total_files_moved']['imgs']} 個檔案")
            print(f"- 遮罩 (masks): {stats['total_files_moved']['masks']} 個檔案")
            
            print("\n各資料夾處理統計：")
            for source, counts in stats['files_per_source'].items():
                print(f"- {source}:")
                print(f"  - 圖片 (imgs): {counts['imgs']} 個檔案")
                print(f"  - 遮罩 (masks): {counts['masks']} 個檔案")
            
            if stats['file_types_found']:
                print("\n發現的檔案類型：")
                for ext in sorted(stats['file_types_found']):
                    print(f"- {ext}")
            
    except Exception as e:
        print(f"\n錯誤: 執行過程中發生錯誤: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# === 開始執行合併作業 ===
# 基礎路徑: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031
# 目標資料夾: 20241031dataset
#
# 檢查來源資料夾: 20241031_train_IW
#
# 處理 train 資料夾:
#   檢查 imgs 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\train\imgs
#     複製檔案: 201905080700.png → 201905080700.png
#     複製檔案: 201905080710.png → 201905080710.png
#     複製檔案: 201905080720.png → 201905080720.png
#     複製檔案: 201905080740.png → 201905080740.png
#     複製檔案: 201905080750.png → 201905080750.png
#     複製檔案: 201905080800.png → 201905080800.png
#     複製檔案: 201905080810.png → 201905080810.png
#     複製檔案: 202106250620.png → 202106250620.png
#     複製檔案: 202106250630.png → 202106250630.png
#   檢查 masks 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\train\masks
#     複製檔案: 201905080700_mask.png → 201905080700_mask.png
#     複製檔案: 201905080710_mask.png → 201905080710_mask.png
#     複製檔案: 201905080720_mask.png → 201905080720_mask.png
#     複製檔案: 201905080740_mask.png → 201905080740_mask.png
#     複製檔案: 201905080750_mask.png → 201905080750_mask.png
#     複製檔案: 201905080800_mask.png → 201905080800_mask.png
#     複製檔案: 201905080810_mask.png → 201905080810_mask.png
#     複製檔案: 201905080820_mask.png → 201905080820_mask.png
#     複製檔案: 201905080830_mask.png → 201905080830_mask.png
#     複製檔案: 201905080840_mask.png → 201905080840_mask.png
#     複製檔案: 201905080850_mask.png → 201905080850_mask.png
#     複製檔案: 201905090740_mask.png → 201905090740_mask.png
#     複製檔案: 201906040250_mask.png → 201906040250_mask.png
#     複製檔案: 201906040300_mask.png → 201906040300_mask.png
#     複製檔案: 201906040310_mask.png → 201906040310_mask.png
#     複製檔案: 201906040320_mask.png → 201906040320_mask.png
#     複製檔案: 201906040330_mask.png → 201906040330_mask.png
#     複製檔案: 201906040410_mask.png → 201906040410_mask.png
#     複製檔案: 201906040420_mask.png → 201906040420_mask.png
#     複製檔案: 201906040430_mask.png → 201906040430_mask.png
#     複製檔案: 201906040450_mask.png → 201906040450_mask.png
#     複製檔案: 201906040500_mask.png → 201906040500_mask.png
#     複製檔案: 201906040510_mask.png → 201906040510_mask.png
#     複製檔案: 201906040520_mask.png → 201906040520_mask.png
#     複製檔案: 201906040540_mask.png → 201906040540_mask.png
#     複製檔案: 201906040620_mask.png → 201906040620_mask.png
#     複製檔案: 201906040630_mask.png → 201906040630_mask.png
#     複製檔案: 201906040640_mask.png → 201906040640_mask.png
#     複製檔案: 201906040700_mask.png → 201906040700_mask.png
#     複製檔案: 201906040710_mask.png → 201906040710_mask.png
#     複製檔案: 201906040720_mask.png → 201906040720_mask.png
#     複製檔案: 201906040740_mask.png → 201906040740_mask.png
#     複製檔案: 201906050530_mask.png → 201906050530_mask.png
#     複製檔案: 201906050550_mask.png → 201906050550_mask.png
#     複製檔案: 201906050620_mask.png → 201906050620_mask.png
#     複製檔案: 201906050630_mask.png → 201906050630_mask.png
#     複製檔案: 201906050640_mask.png → 201906050640_mask.png
#     複製檔案: 201906050710_mask.png → 201906050710_mask.png
#     複製檔案: 201906050720_mask.png → 201906050720_mask.png
#     複製檔案: 201906050730_mask.png → 201906050730_mask.png
#     複製檔案: 201906050740_mask.png → 201906050740_mask.png
#     複製檔案: 201906050750_mask.png → 201906050750_mask.png
#     複製檔案: 201906050810_mask.png → 201906050810_mask.png
#     複製檔案: 201906050820_mask.png → 201906050820_mask.png
#     複製檔案: 201906050830_mask.png → 201906050830_mask.png
#     複製檔案: 201906050840_mask.png → 201906050840_mask.png
#     複製檔案: 201906050850_mask.png → 201906050850_mask.png
#     複製檔案: 201906060400_mask.png → 201906060400_mask.png
#     複製檔案: 201906060430_mask.png → 201906060430_mask.png
#     複製檔案: 201906060450_mask.png → 201906060450_mask.png
#     複製檔案: 201906060500_mask.png → 201906060500_mask.png
#     複製檔案: 201906060510_mask.png → 201906060510_mask.png
#     複製檔案: 201906060520_mask.png → 201906060520_mask.png
#     複製檔案: 201906060530_mask.png → 201906060530_mask.png
#     複製檔案: 201906060550_mask.png → 201906060550_mask.png
#     複製檔案: 201906060610_mask.png → 201906060610_mask.png
#     複製檔案: 201906060630_mask.png → 201906060630_mask.png
#     複製檔案: 201906060640_mask.png → 201906060640_mask.png
#     複製檔案: 201906060650_mask.png → 201906060650_mask.png
#     複製檔案: 201906060710_mask.png → 201906060710_mask.png
#     複製檔案: 201906060720_mask.png → 201906060720_mask.png
#     複製檔案: 201906060730_mask.png → 201906060730_mask.png
#     複製檔案: 201906060740_mask.png → 201906060740_mask.png
#     複製檔案: 201906060750_mask.png → 201906060750_mask.png
#     複製檔案: 201906060800_mask.png → 201906060800_mask.png
#     複製檔案: 201906060810_mask.png → 201906060810_mask.png
#     複製檔案: 201906060820_mask.png → 201906060820_mask.png
#     複製檔案: 201906060830_mask.png → 201906060830_mask.png
#     複製檔案: 201906060850_mask.png → 201906060850_mask.png
#     複製檔案: 201906060910_mask.png → 201906060910_mask.png
#     複製檔案: 201906060920_mask.png → 201906060920_mask.png
#     複製檔案: 201906060940_mask.png → 201906060940_mask.png
#     複製檔案: 201906060950_mask.png → 201906060950_mask.png
#     複製檔案: 201906061000_mask.png → 201906061000_mask.png
#     複製檔案: 201906061010_mask.png → 201906061010_mask.png
#     複製檔案: 201906061020_mask.png → 201906061020_mask.png
#     複製檔案: 201906080720_mask.png → 201906080720_mask.png
#     複製檔案: 201906080800_mask.png → 201906080800_mask.png
#     複製檔案: 201906080820_mask.png → 201906080820_mask.png
#     複製檔案: 201906080850_mask.png → 201906080850_mask.png
#     複製檔案: 201906180320_mask.png → 201906180320_mask.png
#     複製檔案: 201906180340_mask.png → 201906180340_mask.png
#     複製檔案: 201906180350_mask.png → 201906180350_mask.png
#     複製檔案: 201906180400_mask.png → 201906180400_mask.png
#     複製檔案: 201906180410_mask.png → 201906180410_mask.png
#     複製檔案: 201906180440_mask.png → 201906180440_mask.png
#     複製檔案: 201906180450_mask.png → 201906180450_mask.png
#     複製檔案: 201906180500_mask.png → 201906180500_mask.png
#     複製檔案: 201906180540_mask.png → 201906180540_mask.png
#     複製檔案: 201906180550_mask.png → 201906180550_mask.png
#     複製檔案: 201906180600_mask.png → 201906180600_mask.png
#     複製檔案: 201906180610_mask.png → 201906180610_mask.png
#     複製檔案: 201906180720_mask.png → 201906180720_mask.png
#     複製檔案: 201906180740_mask.png → 201906180740_mask.png
#     複製檔案: 201906180800_mask.png → 201906180800_mask.png
#     複製檔案: 201906180810_mask.png → 201906180810_mask.png
#     複製檔案: 201909010520_mask.png → 201909010520_mask.png
#     複製檔案: 201909010530_mask.png → 201909010530_mask.png
#     複製檔案: 201909010540_mask.png → 201909010540_mask.png
#     複製檔案: 201909020510_mask.png → 201909020510_mask.png
#     複製檔案: 201909020550_mask.png → 201909020550_mask.png
#     複製檔案: 201909020600_mask.png → 201909020600_mask.png
#     複製檔案: 201909020610_mask.png → 201909020610_mask.png
#     複製檔案: 201909020620_mask.png → 201909020620_mask.png
#     複製檔案: 201909020730_mask.png → 201909020730_mask.png
#     複製檔案: 201909020820_mask.png → 201909020820_mask.png
#     複製檔案: 201909020840_mask.png → 201909020840_mask.png
#     複製檔案: 201909020900_mask.png → 201909020900_mask.png
#     複製檔案: 202005090340_mask.png → 202005090340_mask.png
#     複製檔案: 202005090350_mask.png → 202005090350_mask.png
#     複製檔案: 202005090410_mask.png → 202005090410_mask.png
#     複製檔案: 202005090420_mask.png → 202005090420_mask.png
#     複製檔案: 202005090430_mask.png → 202005090430_mask.png
#     複製檔案: 202005090440_mask.png → 202005090440_mask.png
#     複製檔案: 202005090500_mask.png → 202005090500_mask.png
#     複製檔案: 202005090510_mask.png → 202005090510_mask.png
#     複製檔案: 202005090520_mask.png → 202005090520_mask.png
#     複製檔案: 202005090530_mask.png → 202005090530_mask.png
#     複製檔案: 202005090540_mask.png → 202005090540_mask.png
#     複製檔案: 202005090600_mask.png → 202005090600_mask.png
#     複製檔案: 202005090700_mask.png → 202005090700_mask.png
#     複製檔案: 202005090720_mask.png → 202005090720_mask.png
#     複製檔案: 202005090740_mask.png → 202005090740_mask.png
#     複製檔案: 202005090750_mask.png → 202005090750_mask.png
#     複製檔案: 202005090800_mask.png → 202005090800_mask.png
#     複製檔案: 202005090820_mask.png → 202005090820_mask.png
#     複製檔案: 202005090850_mask.png → 202005090850_mask.png
#     複製檔案: 202005100410_mask.png → 202005100410_mask.png
#     複製檔案: 202005100420_mask.png → 202005100420_mask.png
#     複製檔案: 202005100440_mask.png → 202005100440_mask.png
#     複製檔案: 202005100450_mask.png → 202005100450_mask.png
#     複製檔案: 202005100500_mask.png → 202005100500_mask.png
#     複製檔案: 202005100530_mask.png → 202005100530_mask.png
#     複製檔案: 202005100540_mask.png → 202005100540_mask.png
#     複製檔案: 202005100550_mask.png → 202005100550_mask.png
#     複製檔案: 202005100600_mask.png → 202005100600_mask.png
#     複製檔案: 202005100610_mask.png → 202005100610_mask.png
#     複製檔案: 202005100620_mask.png → 202005100620_mask.png
#     複製檔案: 202005100630_mask.png → 202005100630_mask.png
#     複製檔案: 202005100650_mask.png → 202005100650_mask.png
#     複製檔案: 202005100720_mask.png → 202005100720_mask.png
#     複製檔案: 202005100730_mask.png → 202005100730_mask.png
#     複製檔案: 202005100740_mask.png → 202005100740_mask.png
#     複製檔案: 202005100810_mask.png → 202005100810_mask.png
#     複製檔案: 202005100820_mask.png → 202005100820_mask.png
#     複製檔案: 202005100830_mask.png → 202005100830_mask.png
#     複製檔案: 202005100840_mask.png → 202005100840_mask.png
#     複製檔案: 202005100850_mask.png → 202005100850_mask.png
#     複製檔案: 202005260850_mask.png → 202005260850_mask.png
#     複製檔案: 202005260910_mask.png → 202005260910_mask.png
#     複製檔案: 202006050530_mask.png → 202006050530_mask.png
#     複製檔案: 202006050550_mask.png → 202006050550_mask.png
#     複製檔案: 202006050600_mask.png → 202006050600_mask.png
#     複製檔案: 202006090330_mask.png → 202006090330_mask.png
#     複製檔案: 202006090340_mask.png → 202006090340_mask.png
#     複製檔案: 202006090350_mask.png → 202006090350_mask.png
#     複製檔案: 202006090400_mask.png → 202006090400_mask.png
#     複製檔案: 202006090410_mask.png → 202006090410_mask.png
#     複製檔案: 202006090420_mask.png → 202006090420_mask.png
#     複製檔案: 202006090430_mask.png → 202006090430_mask.png
#     複製檔案: 202006090450_mask.png → 202006090450_mask.png
#     複製檔案: 202006090500_mask.png → 202006090500_mask.png
#     複製檔案: 202006090620_mask.png → 202006090620_mask.png
#     複製檔案: 202006090720_mask.png → 202006090720_mask.png
#     複製檔案: 202006090730_mask.png → 202006090730_mask.png
#     複製檔案: 202006090740_mask.png → 202006090740_mask.png
#     複製檔案: 202006090750_mask.png → 202006090750_mask.png
#     複製檔案: 202006090800_mask.png → 202006090800_mask.png
#     複製檔案: 202006100440_mask.png → 202006100440_mask.png
#     複製檔案: 202006100450_mask.png → 202006100450_mask.png
#     複製檔案: 202006100500_mask.png → 202006100500_mask.png
#     複製檔案: 202006100510_mask.png → 202006100510_mask.png
#     複製檔案: 202006100520_mask.png → 202006100520_mask.png
#     複製檔案: 202006100530_mask.png → 202006100530_mask.png
#     複製檔案: 202006100540_mask.png → 202006100540_mask.png
#     複製檔案: 202006100550_mask.png → 202006100550_mask.png
#     複製檔案: 202006100600_mask.png → 202006100600_mask.png
#     複製檔案: 202006100610_mask.png → 202006100610_mask.png
#     複製檔案: 202006100630_mask.png → 202006100630_mask.png
#     複製檔案: 202006100640_mask.png → 202006100640_mask.png
#     複製檔案: 202006100700_mask.png → 202006100700_mask.png
#     複製檔案: 202006100710_mask.png → 202006100710_mask.png
#     複製檔案: 202006100730_mask.png → 202006100730_mask.png
#     複製檔案: 202006100810_mask.png → 202006100810_mask.png
#     複製檔案: 202006250550_mask.png → 202006250550_mask.png
#     複製檔案: 202006250600_mask.png → 202006250600_mask.png
#     複製檔案: 202006250610_mask.png → 202006250610_mask.png
#     複製檔案: 202006250620_mask.png → 202006250620_mask.png
#     複製檔案: 202006250730_mask.png → 202006250730_mask.png
#     複製檔案: 202006250740_mask.png → 202006250740_mask.png
#     複製檔案: 202006250750_mask.png → 202006250750_mask.png
#     複製檔案: 202006250810_mask.png → 202006250810_mask.png
#     複製檔案: 202006250820_mask.png → 202006250820_mask.png
#     複製檔案: 202006250830_mask.png → 202006250830_mask.png
#     複製檔案: 202006250840_mask.png → 202006250840_mask.png
#     複製檔案: 202007080800_mask.png → 202007080800_mask.png
#     複製檔案: 202007080810_mask.png → 202007080810_mask.png
#     複製檔案: 202007080840_mask.png → 202007080840_mask.png
#     複製檔案: 202007080850_mask.png → 202007080850_mask.png
#     複製檔案: 202007080910_mask.png → 202007080910_mask.png
#     複製檔案: 202007202130_mask.png → 202007202130_mask.png
#     複製檔案: 202007202150_mask.png → 202007202150_mask.png
#     複製檔案: 202007202220_mask.png → 202007202220_mask.png
#     複製檔案: 202007202250_mask.png → 202007202250_mask.png
#     複製檔案: 202007202300_mask.png → 202007202300_mask.png
#     複製檔案: 202007202310_mask.png → 202007202310_mask.png
#     複製檔案: 202007202320_mask.png → 202007202320_mask.png
#     複製檔案: 202007202340_mask.png → 202007202340_mask.png
#     複製檔案: 202007210120_mask.png → 202007210120_mask.png
#     複製檔案: 202007210130_mask.png → 202007210130_mask.png
#     複製檔案: 202007210140_mask.png → 202007210140_mask.png
#     複製檔案: 202007210150_mask.png → 202007210150_mask.png
#     複製檔案: 202007210200_mask.png → 202007210200_mask.png
#     複製檔案: 202007210510_mask.png → 202007210510_mask.png
#     複製檔案: 202007210530_mask.png → 202007210530_mask.png
#     複製檔案: 202007210540_mask.png → 202007210540_mask.png
#     複製檔案: 202007210620_mask.png → 202007210620_mask.png
#     複製檔案: 202007210700_mask.png → 202007210700_mask.png
#     複製檔案: 202007220440_mask.png → 202007220440_mask.png
#     複製檔案: 202007220450_mask.png → 202007220450_mask.png
#     複製檔案: 202007220500_mask.png → 202007220500_mask.png
#     複製檔案: 202007220510_mask.png → 202007220510_mask.png
#     複製檔案: 202007220530_mask.png → 202007220530_mask.png
#     複製檔案: 202007220540_mask.png → 202007220540_mask.png
#     複製檔案: 202007220550_mask.png → 202007220550_mask.png
#     複製檔案: 202007220600_mask.png → 202007220600_mask.png
#     複製檔案: 202007220620_mask.png → 202007220620_mask.png
#     複製檔案: 202007220640_mask.png → 202007220640_mask.png
#     複製檔案: 202007220650_mask.png → 202007220650_mask.png
#     複製檔案: 202007220720_mask.png → 202007220720_mask.png
#     複製檔案: 202007220730_mask.png → 202007220730_mask.png
#     複製檔案: 202007220740_mask.png → 202007220740_mask.png
#     複製檔案: 202007220750_mask.png → 202007220750_mask.png
#     複製檔案: 202007220820_mask.png → 202007220820_mask.png
#     複製檔案: 202007220830_mask.png → 202007220830_mask.png
#     複製檔案: 202007220840_mask.png → 202007220840_mask.png
#     複製檔案: 202007220850_mask.png → 202007220850_mask.png
#     複製檔案: 202104300550_mask.png → 202104300550_mask.png
#     複製檔案: 202104300600_mask.png → 202104300600_mask.png
#     複製檔案: 202104300610_mask.png → 202104300610_mask.png
#     複製檔案: 202104300640_mask.png → 202104300640_mask.png
#     複製檔案: 202104300700_mask.png → 202104300700_mask.png
#     複製檔案: 202105010420_mask.png → 202105010420_mask.png
#     複製檔案: 202105010430_mask.png → 202105010430_mask.png
#     複製檔案: 202105150530_mask.png → 202105150530_mask.png
#     複製檔案: 202105150550_mask.png → 202105150550_mask.png
#     複製檔案: 202105150600_mask.png → 202105150600_mask.png
#     複製檔案: 202105150620_mask.png → 202105150620_mask.png
#     複製檔案: 202105150630_mask.png → 202105150630_mask.png
#     複製檔案: 202105150650_mask.png → 202105150650_mask.png
#     複製檔案: 202105150700_mask.png → 202105150700_mask.png
#     複製檔案: 202007202330.png → 202007202330.png
#     複製檔案: 202007210630.png → 202007210630.png
#     複製檔案: 202007220430.png → 202007220430.png
#     複製檔案: 202007220630.png → 202007220630.png
#     複製檔案: 202007220700.png → 202007220700.png
#     複製檔案: 202104300540.png → 202104300540.png
#     複製檔案: 202105010410.png → 202105010410.png
#     複製檔案: 202105150610.png → 202105150610.png
#     複製檔案: 202105150640.png → 202105150640.png
#     複製檔案: 202105150740.png → 202105150740.png
#     複製檔案: 202105150820.png → 202105150820.png
#     複製檔案: 202106250420.png → 202106250420.png
#     複製檔案: 202106250550.png → 202106250550.png
#   檢查 masks 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\val\masks
#     複製檔案: 201906040350_mask.png → 201906040350_mask.png
#     複製檔案: 201906040400_mask.png → 201906040400_mask.png
#     複製檔案: 201906040440_mask.png → 201906040440_mask.png
#     複製檔案: 201906040530_mask.png → 201906040530_mask.png
#     複製檔案: 201906040550_mask.png → 201906040550_mask.png
#     複製檔案: 201906040600_mask.png → 201906040600_mask.png
#     複製檔案: 201906040750_mask.png → 201906040750_mask.png
#     複製檔案: 201906050600_mask.png → 201906050600_mask.png
#     複製檔案: 201906050650_mask.png → 201906050650_mask.png
#     複製檔案: 201906060410_mask.png → 201906060410_mask.png
#     複製檔案: 201906060440_mask.png → 201906060440_mask.png
#     複製檔案: 201906060620_mask.png → 201906060620_mask.png
#     複製檔案: 201906060700_mask.png → 201906060700_mask.png
#     複製檔案: 201906060900_mask.png → 201906060900_mask.png
#     複製檔案: 201906070940_mask.png → 201906070940_mask.png
#     複製檔案: 201906080710_mask.png → 201906080710_mask.png
#     複製檔案: 201906080830_mask.png → 201906080830_mask.png
#     複製檔案: 201906080840_mask.png → 201906080840_mask.png
#     複製檔案: 201906180430_mask.png → 201906180430_mask.png
#     複製檔案: 201906180620_mask.png → 201906180620_mask.png
#     複製檔案: 201906180650_mask.png → 201906180650_mask.png
#     複製檔案: 201906180700_mask.png → 201906180700_mask.png
#     複製檔案: 201906180710_mask.png → 201906180710_mask.png
#     複製檔案: 201909010600_mask.png → 201909010600_mask.png
#     複製檔案: 202005090400_mask.png → 202005090400_mask.png
#     複製檔案: 202005090450_mask.png → 202005090450_mask.png
#     複製檔案: 202005090810_mask.png → 202005090810_mask.png
#     複製檔案: 202005100340_mask.png → 202005100340_mask.png
#     複製檔案: 202005100430_mask.png → 202005100430_mask.png
#     複製檔案: 202005100640_mask.png → 202005100640_mask.png
#     複製檔案: 202005100700_mask.png → 202005100700_mask.png
#     複製檔案: 202005100710_mask.png → 202005100710_mask.png
#     複製檔案: 202006050540_mask.png → 202006050540_mask.png
#     複製檔案: 202006090510_mask.png → 202006090510_mask.png
#     複製檔案: 202006090630_mask.png → 202006090630_mask.png
#     複製檔案: 202006090650_mask.png → 202006090650_mask.png
#     複製檔案: 202006100620_mask.png → 202006100620_mask.png
#     複製檔案: 202006100650_mask.png → 202006100650_mask.png
#     複製檔案: 202006100800_mask.png → 202006100800_mask.png
#     複製檔案: 202006250850_mask.png → 202006250850_mask.png
#     複製檔案: 202007202200_mask.png → 202007202200_mask.png
#     複製檔案: 202007202210_mask.png → 202007202210_mask.png
#     複製檔案: 202007202240_mask.png → 202007202240_mask.png
#     複製檔案: 202007202330_mask.png → 202007202330_mask.png
#     複製檔案: 202007210630_mask.png → 202007210630_mask.png
#     複製檔案: 202007220430_mask.png → 202007220430_mask.png
#     複製檔案: 202007220630_mask.png → 202007220630_mask.png
#     複製檔案: 202007220700_mask.png → 202007220700_mask.png
#     複製檔案: 202104300540_mask.png → 202104300540_mask.png
#     複製檔案: 202105010410_mask.png → 202105010410_mask.png
#     複製檔案: 202105150610_mask.png → 202105150610_mask.png
#     複製檔案: 202105150640_mask.png → 202105150640_mask.png
#     複製檔案: 202105150740_mask.png → 202105150740_mask.png
#     複製檔案: 202105150820_mask.png → 202105150820_mask.png
#     複製檔案: 202106250420_mask.png → 202106250420_mask.png
#     複製檔案: 202106250550_mask.png → 202106250550_mask.png
#
# 處理 test 資料夾:
#   檢查 imgs 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\test\imgs
#     複製檔案: 201905080730.png → 201905080730.png
#     複製檔案: 201905080900.png → 201905080900.png
#     複製檔案: 201905090730.png → 201905090730.png
#     複製檔案: 201905090750.png → 201905090750.png
#     複製檔案: 201905090800.png → 201905090800.png
#     複製檔案: 201906040340.png → 201906040340.png
#     複製檔案: 201906040650.png → 201906040650.png
#     複製檔案: 201906040730.png → 201906040730.png
#     複製檔案: 201906040800.png → 201906040800.png
#     複製檔案: 201906050540.png → 201906050540.png
#     複製檔案: 201906050610.png → 201906050610.png
#     複製檔案: 201906050700.png → 201906050700.png
#     複製檔案: 201906050800.png → 201906050800.png
#     複製檔案: 201906060420.png → 201906060420.png
#     複製檔案: 201906060540.png → 201906060540.png
#     複製檔案: 201906060600.png → 201906060600.png
#     複製檔案: 201906060930.png → 201906060930.png
#     複製檔案: 201906080730.png → 201906080730.png
#     複製檔案: 201906080740.png → 201906080740.png
#     複製檔案: 201906080750.png → 201906080750.png
#     複製檔案: 201906080810.png → 201906080810.png
#     複製檔案: 201906180310.png → 201906180310.png
#     複製檔案: 201906180420.png → 201906180420.png
#     複製檔案: 201906180630.png → 201906180630.png
#     複製檔案: 201906180730.png → 201906180730.png
#     複製檔案: 201906180750.png → 201906180750.png
#     複製檔案: 201909020520.png → 201909020520.png
#     複製檔案: 202005090550.png → 202005090550.png
#     複製檔案: 202005090620.png → 202005090620.png
#     複製檔案: 202005090710.png → 202005090710.png
#     複製檔案: 202005090840.png → 202005090840.png
#     複製檔案: 202005090910.png → 202005090910.png
#     複製檔案: 202005100510.png → 202005100510.png
#     複製檔案: 202005100520.png → 202005100520.png
#     複製檔案: 202005100900.png → 202005100900.png
#     複製檔案: 202005260900.png → 202005260900.png
#     複製檔案: 202006090440.png → 202006090440.png
#     複製檔案: 202006090640.png → 202006090640.png
#     複製檔案: 202006100720.png → 202006100720.png
#     複製檔案: 202007080740.png → 202007080740.png
#     複製檔案: 202007080900.png → 202007080900.png
#     複製檔案: 202007202140.png → 202007202140.png
#     複製檔案: 202007202230.png → 202007202230.png
#     複製檔案: 202007210110.png → 202007210110.png
#     複製檔案: 202007210210.png → 202007210210.png
#     複製檔案: 202007210500.png → 202007210500.png
#     複製檔案: 202007210640.png → 202007210640.png
#     複製檔案: 202007210650.png → 202007210650.png
#     複製檔案: 202007220520.png → 202007220520.png
#     複製檔案: 202007220610.png → 202007220610.png
#     複製檔案: 202007220710.png → 202007220710.png
#     複製檔案: 202007220800.png → 202007220800.png
#     複製檔案: 202105150520.png → 202105150520.png
#     複製檔案: 202105150540.png → 202105150540.png
#     複製檔案: 202105150800.png → 202105150800.png
#     複製檔案: 202105150830.png → 202105150830.png
#     複製檔案: 202106250350.png → 202106250350.png
#     複製檔案: 202106250410.png → 202106250410.png
#   檢查 masks 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_IW\test\masks
#     複製檔案: 201905080730_mask.png → 201905080730_mask.png
#     複製檔案: 201905080900_mask.png → 201905080900_mask.png
#     複製檔案: 201905090730_mask.png → 201905090730_mask.png
#     複製檔案: 201905090750_mask.png → 201905090750_mask.png
#     複製檔案: 201905090800_mask.png → 201905090800_mask.png
#     複製檔案: 201906040340_mask.png → 201906040340_mask.png
#     複製檔案: 201906040650_mask.png → 201906040650_mask.png
#     複製檔案: 201906040730_mask.png → 201906040730_mask.png
#     複製檔案: 201906040800_mask.png → 201906040800_mask.png
#     複製檔案: 201906050540_mask.png → 201906050540_mask.png
#     複製檔案: 201906050610_mask.png → 201906050610_mask.png
#     複製檔案: 201906050700_mask.png → 201906050700_mask.png
#     複製檔案: 201906050800_mask.png → 201906050800_mask.png
#     複製檔案: 201906060420_mask.png → 201906060420_mask.png
#     複製檔案: 201906060540_mask.png → 201906060540_mask.png
#     複製檔案: 201906060600_mask.png → 201906060600_mask.png
#     複製檔案: 201906060930_mask.png → 201906060930_mask.png
#     複製檔案: 201906080730_mask.png → 201906080730_mask.png
#     複製檔案: 201906080740_mask.png → 201906080740_mask.png
#     複製檔案: 201906080750_mask.png → 201906080750_mask.png
#     複製檔案: 201906080810_mask.png → 201906080810_mask.png
#     複製檔案: 201906180310_mask.png → 201906180310_mask.png
#     複製檔案: 201906180420_mask.png → 201906180420_mask.png
#     複製檔案: 201906180630_mask.png → 201906180630_mask.png
#     複製檔案: 201906180730_mask.png → 201906180730_mask.png
#     複製檔案: 201906180750_mask.png → 201906180750_mask.png
#     複製檔案: 201909020520_mask.png → 201909020520_mask.png
#     複製檔案: 202005090550_mask.png → 202005090550_mask.png
#     複製檔案: 202005090620_mask.png → 202005090620_mask.png
#     複製檔案: 202005090710_mask.png → 202005090710_mask.png
#     複製檔案: 202005090840_mask.png → 202005090840_mask.png
#     複製檔案: 202005090910_mask.png → 202005090910_mask.png
#     複製檔案: 202005100510_mask.png → 202005100510_mask.png
#     複製檔案: 202005100520_mask.png → 202005100520_mask.png
#     複製檔案: 202005100900_mask.png → 202005100900_mask.png
#     複製檔案: 202005260900_mask.png → 202005260900_mask.png
#     複製檔案: 202006090440_mask.png → 202006090440_mask.png
#     複製檔案: 202006090640_mask.png → 202006090640_mask.png
#     複製檔案: 202006100720_mask.png → 202006100720_mask.png
#     複製檔案: 202007080740_mask.png → 202007080740_mask.png
#     複製檔案: 202007080900_mask.png → 202007080900_mask.png
#     複製檔案: 202007202140_mask.png → 202007202140_mask.png
#     複製檔案: 202007202230_mask.png → 202007202230_mask.png
#     複製檔案: 202007210110_mask.png → 202007210110_mask.png
#     複製檔案: 202007210210_mask.png → 202007210210_mask.png
#     複製檔案: 202007210500_mask.png → 202007210500_mask.png
#     複製檔案: 202007210640_mask.png → 202007210640_mask.png
#     複製檔案: 202007210650_mask.png → 202007210650_mask.png
#     複製檔案: 202007220520_mask.png → 202007220520_mask.png
#     複製檔案: 202007220610_mask.png → 202007220610_mask.png
#     複製檔案: 202007220710_mask.png → 202007220710_mask.png
#     複製檔案: 202007220800_mask.png → 202007220800_mask.png
#     複製檔案: 202105150520_mask.png → 202105150520_mask.png
#     複製檔案: 202105150540_mask.png → 202105150540_mask.png
#     複製檔案: 202105150800_mask.png → 202105150800_mask.png
#     複製檔案: 202105150830_mask.png → 202105150830_mask.png
#     複製檔案: 202106250350_mask.png → 202106250350_mask.png
#     複製檔案: 202106250410_mask.png → 202106250410_mask.png
#
# 檢查來源資料夾: 20241031_train_noIW
#
# 處理 train 資料夾:
#   檢查 imgs 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_noIW\train\imgs
#     複製檔案: 201905070920.png → 201905070920.png
#     複製檔案: 201905070930.png → 201905070930.png
#     複製檔案: 201905070950.png → 201905070950.png
#     複製檔案: 201905071000.png → 201905071000.png
#     複製檔案: 201905071010.png → 201905071010.png
#     複製檔案: 201905072130.png → 201905072130.png
#     複製檔案: 201905072140.png → 201905072140.png
#     複製檔案: 201905072150.png → 201905072150.png
#     複製檔案: 201905072210.png → 201905072210.png
#     複製檔案: 201905072230.png → 201905072230.png
#     複製檔案: 201905072250.png → 201905072250.png
#     複製檔案: 201905072300.png → 201905072300.png
#     複製檔案: 201905072310.png → 201905072310.png
#     複製檔案: 201905072330.png → 201905072330.png
#     複製檔案: 201905072350.png → 201905072350.png
#     複製檔案: 201905080000.png → 201905080000.png
#     複製檔案: 201905080010.png → 201905080010.png
#     複製檔案: 201905080020.png → 201905080020.png
#     複製檔案: 201905080030.png → 201905080030.png
#     複製檔案: 201905080040.png → 201905080040.png
#     複製檔案: 201905080050.png → 201905080050.png
#     複製檔案: 201905080100.png → 201905080100.png
#     複製檔案: 201905080110.png → 201905080110.png
#     複製檔案: 201906050410.png → 201906050410.png
#     複製檔案: 201906050420.png → 201906050420.png
#     複製檔案: 201906050440.png → 201906050440.png
#     複製檔案: 201906050450.png → 201906050450.png
#     複製檔案: 201906050510.png → 201906050510.png
#     複製檔案: 201906050520.png → 201906050520.png
#     複製檔案: 201908310910.png → 201908310910.png
#     複製檔案: 201908310930.png → 201908310930.png
#     複製檔案: 201908310940.png → 201908310940.png
#     複製檔案: 201908310950.png → 201908310950.png
#     複製檔案: 201908311000.png → 201908311000.png
#     複製檔案: 201908312140.png → 201908312140.png
#     複製檔案: 201908312220.png → 201908312220.png
#     複製檔案: 201908312230.png → 201908312230.png
#     複製檔案: 201908312250.png → 201908312250.png
#     複製檔案: 201908312300.png → 201908312300.png
#     複製檔案: 201908312310.png → 201908312310.png
#     複製檔案: 201908312320.png → 201908312320.png
#     複製檔案: 201908312330.png → 201908312330.png
#     複製檔案: 201908312340.png → 201908312340.png
#     複製檔案: 201908312350.png → 201908312350.png
#     複製檔案: 201909010000.png → 201909010000.png
#     複製檔案: 201909010010.png → 201909010010.png
#     複製檔案: 201909010030.png → 201909010030.png
#     複製檔案: 201909010040.png → 201909010040.png
#     複製檔案: 201909010050.png → 201909010050.png
#     複製檔案: 201909010100.png → 201909010100.png
#     複製檔案: 201909010120.png → 201909010120.png
#     複製檔案: 201909010140.png → 201909010140.png
#     複製檔案: 201909010220.png → 201909010220.png
#     複製檔案: 201909010300.png → 201909010300.png
#     複製檔案: 201909010310.png → 201909010310.png
#     複製檔案: 201909010320.png → 201909010320.png
#     複製檔案: 201909010330.png → 201909010330.png
#     複製檔案: 201909010350.png → 201909010350.png
#     複製檔案: 201909010400.png → 201909010400.png
#     複製檔案: 201909010420.png → 201909010420.png
#     複製檔案: 201909010430.png → 201909010430.png
#     複製檔案: 201909010440.png → 201909010440.png
#     複製檔案: 201909010710.png → 201909010710.png
#     複製檔案: 201909010720.png → 201909010720.png
#     複製檔案: 201909010730.png → 201909010730.png
#     複製檔案: 201909010740.png → 201909010740.png
#     複製檔案: 201909010800.png → 201909010800.png
#     複製檔案: 201909010820.png → 201909010820.png
#     複製檔案: 201909010840.png → 201909010840.png
#     複製檔案: 201909010850.png → 201909010850.png
#     複製檔案: 201909010910.png → 201909010910.png
#     複製檔案: 201909010930.png → 201909010930.png
#     複製檔案: 201909010950.png → 201909010950.png
#     複製檔案: 201909011000.png → 201909011000.png
#     複製檔案: 201909012150.png → 201909012150.png
#     複製檔案: 201909012200.png → 201909012200.png
#     複製檔案: 201909012220.png → 201909012220.png
#     複製檔案: 201909012250.png → 201909012250.png
#     複製檔案: 201909012300.png → 201909012300.png
#     複製檔案: 201909012320.png → 201909012320.png
#     複製檔案: 201909012330.png → 201909012330.png
#     複製檔案: 201909012340.png → 201909012340.png
#     複製檔案: 201909012350.png → 201909012350.png
#     複製檔案: 201909020010.png → 201909020010.png
#     複製檔案: 201909020040.png → 201909020040.png
#     複製檔案: 201909020100.png → 201909020100.png
#     複製檔案: 201909020110.png → 201909020110.png
#     複製檔案: 202006080140.png → 202006080140.png
#     複製檔案: 202006080400.png → 202006080400.png
#     複製檔案: 202006080650.png → 202006080650.png
#     複製檔案: 202006080900.png → 202006080900.png
#     複製檔案: 202006080950.png → 202006080950.png
#     複製檔案: 202006081030.png → 202006081030.png
#     複製檔案: 202006082130.png → 202006082130.png
#     複製檔案: 202006082140.png → 202006082140.png
#     複製檔案: 202006090020.png → 202006090020.png
#     複製檔案: 202104292250.png → 202104292250.png
#     複製檔案: 202104300010.png → 202104300010.png
#     複製檔案: 202104300020.png → 202104300020.png
#     複製檔案: 202104300230.png → 202104300230.png
#     複製檔案: 202104300500.png → 202104300500.png
#     複製檔案: 202104300520.png → 202104300520.png
#     複製檔案: 202104300530.png → 202104300530.png
#     複製檔案: 202104300750.png → 202104300750.png
#     複製檔案: 202104300800.png → 202104300800.png
#     複製檔案: 202104300900.png → 202104300900.png
#     複製檔案: 202104302220.png → 202104302220.png
#     複製檔案: 202104302320.png → 202104302320.png
#     複製檔案: 202105010120.png → 202105010120.png
#     複製檔案: 202105010440.png → 202105010440.png
#     複製檔案: 202105142350.png → 202105142350.png
#     複製檔案: 202105150110.png → 202105150110.png
#     複製檔案: 202105150210.png → 202105150210.png
#     複製檔案: 202105150250.png → 202105150250.png
#     複製檔案: 202105150300.png → 202105150300.png
#     複製檔案: 202105150330.png → 202105150330.png
#     複製檔案: 202105150450.png → 202105150450.png
#     複製檔案: 202105150500.png → 202105150500.png
#     複製檔案: 202105150510.png → 202105150510.png
#     複製檔案: 202106240850.png → 202106240850.png
#     複製檔案: 202106240950.png → 202106240950.png
#     複製檔案: 202106241000.png → 202106241000.png
#     複製檔案: 202106242130.png → 202106242130.png
#     複製檔案: 202106242140.png → 202106242140.png
#     複製檔案: 202106242240.png → 202106242240.png
#     複製檔案: 202106242320.png → 202106242320.png
#     複製檔案: 202106242350.png → 202106242350.png
#   檢查 masks 資料夾: C:\Users\Alan\Dropbox\Himawari8_Wave_Speed_Detection\datas\Band03IW\Original_imgs\NLM\Labeled\訓練資料\20241031\20241031_train_noIW\test\masks
#     複製檔案: 201905072200_mask.png → 201905072200_mask.png
#     複製檔案: 201905072220_mask.png → 201905072220_mask.png
#     複製檔案: 201905080130_mask.png → 201905080130_mask.png
#     複製檔案: 201905080420_mask.png → 201905080420_mask.png
#     複製檔案: 201905080450_mask.png → 201905080450_mask.png
#     複製檔案: 201905080520_mask.png → 201905080520_mask.png
#     複製檔案: 201905080550_mask.png → 201905080550_mask.png
#     複製檔案: 201905080630_mask.png → 201905080630_mask.png
#     複製檔案: 201906030930_mask.png → 201906030930_mask.png
#     複製檔案: 201906030950_mask.png → 201906030950_mask.png
#     複製檔案: 201906032130_mask.png → 201906032130_mask.png
#     複製檔案: 201906040000_mask.png → 201906040000_mask.png
#     複製檔案: 201906040050_mask.png → 201906040050_mask.png
#     複製檔案: 201906050140_mask.png → 201906050140_mask.png
#     複製檔案: 201906050230_mask.png → 201906050230_mask.png
#     複製檔案: 201908312150_mask.png → 201908312150_mask.png
#     複製檔案: 201908312200_mask.png → 201908312200_mask.png
#     複製檔案: 201908312240_mask.png → 201908312240_mask.png
#     複製檔案: 201909010020_mask.png → 201909010020_mask.png
#     複製檔案: 201909010110_mask.png → 201909010110_mask.png
#     複製檔案: 201909010130_mask.png → 201909010130_mask.png
#     複製檔案: 201909010200_mask.png → 201909010200_mask.png
#     複製檔案: 201909010210_mask.png → 201909010210_mask.png
#     複製檔案: 201909010340_mask.png → 201909010340_mask.png
#     複製檔案: 201909010410_mask.png → 201909010410_mask.png
#     複製檔案: 201909010810_mask.png → 201909010810_mask.png
#     複製檔案: 201909010830_mask.png → 201909010830_mask.png
#     複製檔案: 201909010940_mask.png → 201909010940_mask.png
#     複製檔案: 201909012240_mask.png → 201909012240_mask.png
#     複製檔案: 201909012310_mask.png → 201909012310_mask.png
#     複製檔案: 201909020000_mask.png → 201909020000_mask.png
#     複製檔案: 201909020020_mask.png → 201909020020_mask.png
#     複製檔案: 201909020030_mask.png → 201909020030_mask.png
#     複製檔案: 201909020140_mask.png → 201909020140_mask.png
#     複製檔案: 201909020220_mask.png → 201909020220_mask.png
#     複製檔案: 201909020330_mask.png → 201909020330_mask.png
#     複製檔案: 201909022220_mask.png → 201909022220_mask.png
#     複製檔案: 201909022240_mask.png → 201909022240_mask.png
#     複製檔案: 201909022310_mask.png → 201909022310_mask.png
#     複製檔案: 201909022330_mask.png → 201909022330_mask.png
#     複製檔案: 201909030130_mask.png → 201909030130_mask.png
#     複製檔案: 201909030150_mask.png → 201909030150_mask.png
#     複製檔案: 201909030210_mask.png → 201909030210_mask.png
#     複製檔案: 201909030220_mask.png → 201909030220_mask.png
#     複製檔案: 201909030250_mask.png → 201909030250_mask.png
#     複製檔案: 201909030420_mask.png → 201909030420_mask.png
#     複製檔案: 201909030950_mask.png → 201909030950_mask.png
#     複製檔案: 201909032210_mask.png → 201909032210_mask.png
#     複製檔案: 201909032220_mask.png → 201909032220_mask.png
#     複製檔案: 201909032250_mask.png → 201909032250_mask.png
#     複製檔案: 201909032350_mask.png → 201909032350_mask.png
#     複製檔案: 202005090050_mask.png → 202005090050_mask.png
#     複製檔案: 202005090200_mask.png → 202005090200_mask.png
#     複製檔案: 202005090230_mask.png → 202005090230_mask.png
#     複製檔案: 202005090940_mask.png → 202005090940_mask.png
#     複製檔案: 202005092230_mask.png → 202005092230_mask.png
#     複製檔案: 202005092250_mask.png → 202005092250_mask.png
#     複製檔案: 202005092320_mask.png → 202005092320_mask.png
#     複製檔案: 202005092330_mask.png → 202005092330_mask.png
#     複製檔案: 202005100120_mask.png → 202005100120_mask.png
#     複製檔案: 202005100140_mask.png → 202005100140_mask.png
#     複製檔案: 202005100150_mask.png → 202005100150_mask.png
#     複製檔案: 202005100210_mask.png → 202005100210_mask.png
#     複製檔案: 202005110130_mask.png → 202005110130_mask.png
#     複製檔案: 202005110230_mask.png → 202005110230_mask.png
#     複製檔案: 202005110300_mask.png → 202005110300_mask.png
#     複製檔案: 202005110410_mask.png → 202005110410_mask.png
#     複製檔案: 202005110450_mask.png → 202005110450_mask.png
#     複製檔案: 202005110550_mask.png → 202005110550_mask.png
#     複製檔案: 202005110700_mask.png → 202005110700_mask.png
#     複製檔案: 202005110720_mask.png → 202005110720_mask.png
#     複製檔案: 202005110750_mask.png → 202005110750_mask.png
#     複製檔案: 202005110830_mask.png → 202005110830_mask.png
#     複製檔案: 202005110900_mask.png → 202005110900_mask.png
#     複製檔案: 202005261010_mask.png → 202005261010_mask.png
#     複製檔案: 202005270120_mask.png → 202005270120_mask.png
#     複製檔案: 202005270200_mask.png → 202005270200_mask.png
#     複製檔案: 202005270310_mask.png → 202005270310_mask.png
#     複製檔案: 202005270450_mask.png → 202005270450_mask.png
#     複製檔案: 202005270810_mask.png → 202005270810_mask.png
#     複製檔案: 202005270900_mask.png → 202005270900_mask.png
#     複製檔案: 202006040920_mask.png → 202006040920_mask.png
#     複製檔案: 202006040940_mask.png → 202006040940_mask.png
#     複製檔案: 202006042220_mask.png → 202006042220_mask.png
#     複製檔案: 202006042250_mask.png → 202006042250_mask.png
#     複製檔案: 202006042320_mask.png → 202006042320_mask.png
#     複製檔案: 202006042330_mask.png → 202006042330_mask.png
#     複製檔案: 202006050010_mask.png → 202006050010_mask.png
#     複製檔案: 202006050110_mask.png → 202006050110_mask.png
#     複製檔案: 202006050320_mask.png → 202006050320_mask.png
#     複製檔案: 202006050440_mask.png → 202006050440_mask.png
#     複製檔案: 202006050450_mask.png → 202006050450_mask.png
#     複製檔案: 202006050510_mask.png → 202006050510_mask.png
#     複製檔案: 202006050740_mask.png → 202006050740_mask.png
#     複製檔案: 202006050950_mask.png → 202006050950_mask.png
#     複製檔案: 202006052340_mask.png → 202006052340_mask.png
#     複製檔案: 202006060100_mask.png → 202006060100_mask.png
#     複製檔案: 202006060150_mask.png → 202006060150_mask.png
#     複製檔案: 202006060220_mask.png → 202006060220_mask.png
#     複製檔案: 202006060320_mask.png → 202006060320_mask.png
#     複製檔案: 202006060440_mask.png → 202006060440_mask.png
#     複製檔案: 202006060710_mask.png → 202006060710_mask.png
#     複製檔案: 202006060740_mask.png → 202006060740_mask.png
#     複製檔案: 202006060850_mask.png → 202006060850_mask.png
#     複製檔案: 202006060910_mask.png → 202006060910_mask.png
#     複製檔案: 202006060920_mask.png → 202006060920_mask.png
#     複製檔案: 202006060940_mask.png → 202006060940_mask.png
#     複製檔案: 202006061010_mask.png → 202006061010_mask.png
#     複製檔案: 202006062320_mask.png → 202006062320_mask.png
#     複製檔案: 202006070210_mask.png → 202006070210_mask.png
#     複製檔案: 202006070250_mask.png → 202006070250_mask.png
#     複製檔案: 202006070310_mask.png → 202006070310_mask.png
#     複製檔案: 202006070410_mask.png → 202006070410_mask.png
#     複製檔案: 202006070650_mask.png → 202006070650_mask.png
#     複製檔案: 202006070710_mask.png → 202006070710_mask.png
#     複製檔案: 202006070750_mask.png → 202006070750_mask.png
#     複製檔案: 202006070840_mask.png → 202006070840_mask.png
#     複製檔案: 202006070900_mask.png → 202006070900_mask.png
#     複製檔案: 202006070930_mask.png → 202006070930_mask.png
#     複製檔案: 202006072130_mask.png → 202006072130_mask.png
#     複製檔案: 202006072140_mask.png → 202006072140_mask.png
#     複製檔案: 202006072250_mask.png → 202006072250_mask.png
#     複製檔案: 202006080140_mask.png → 202006080140_mask.png
#     複製檔案: 202006080400_mask.png → 202006080400_mask.png
#     複製檔案: 202006080650_mask.png → 202006080650_mask.png
#     複製檔案: 202006080900_mask.png → 202006080900_mask.png
#     複製檔案: 202006080950_mask.png → 202006080950_mask.png
#     複製檔案: 202006081030_mask.png → 202006081030_mask.png
#     複製檔案: 202006082130_mask.png → 202006082130_mask.png
#     複製檔案: 202006082140_mask.png → 202006082140_mask.png
#     複製檔案: 202006090020_mask.png → 202006090020_mask.png
#     複製檔案: 202104292250_mask.png → 202104292250_mask.png
#     複製檔案: 202104300010_mask.png → 202104300010_mask.png
#     複製檔案: 202104300020_mask.png → 202104300020_mask.png
#     複製檔案: 202104300230_mask.png → 202104300230_mask.png
#     複製檔案: 202104300500_mask.png → 202104300500_mask.png
#     複製檔案: 202104300520_mask.png → 202104300520_mask.png
#     複製檔案: 202104300530_mask.png → 202104300530_mask.png
#     複製檔案: 202104300750_mask.png → 202104300750_mask.png
#     複製檔案: 202104300800_mask.png → 202104300800_mask.png
#     複製檔案: 202104300900_mask.png → 202104300900_mask.png
#     複製檔案: 202104302220_mask.png → 202104302220_mask.png
#     複製檔案: 202104302320_mask.png → 202104302320_mask.png
#     複製檔案: 202105010120_mask.png → 202105010120_mask.png
#     複製檔案: 202105010440_mask.png → 202105010440_mask.png
#     複製檔案: 202105142350_mask.png → 202105142350_mask.png
#     複製檔案: 202105150110_mask.png → 202105150110_mask.png
#     複製檔案: 202105150210_mask.png → 202105150210_mask.png
#     複製檔案: 202105150250_mask.png → 202105150250_mask.png
#     複製檔案: 202105150300_mask.png → 202105150300_mask.png
#     複製檔案: 202105150330_mask.png → 202105150330_mask.png
#     複製檔案: 202105150450_mask.png → 202105150450_mask.png
#     複製檔案: 202105150500_mask.png → 202105150500_mask.png
#     複製檔案: 202105150510_mask.png → 202105150510_mask.png
#     複製檔案: 202106240850_mask.png → 202106240850_mask.png
#     複製檔案: 202106240950_mask.png → 202106240950_mask.png
#     複製檔案: 202106241000_mask.png → 202106241000_mask.png
#     複製檔案: 202106242130_mask.png → 202106242130_mask.png
#     複製檔案: 202106242140_mask.png → 202106242140_mask.png
#     複製檔案: 202106242240_mask.png → 202106242240_mask.png
#     複製檔案: 202106242320_mask.png → 202106242320_mask.png
#     複製檔案: 202106242350_mask.png → 202106242350_mask.png
#
# === 處理結果統計 ===
# 總共移動的檔案:
# - 圖片 (imgs): 1454 個檔案
# - 遮罩 (masks): 1454 個檔案
#
# 各資料夾處理統計：
# - 20241031_train_IW:
#   - 圖片 (imgs): 378 個檔案
#   - 遮罩 (masks): 378 個檔案
# - 20241031_train_noIW:
#   - 圖片 (imgs): 1076 個檔案
#   - 遮罩 (masks): 1076 個檔案
#
# 發現的檔案類型：
# - .png
